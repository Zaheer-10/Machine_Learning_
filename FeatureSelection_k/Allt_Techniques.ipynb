# %% [markdown]
# Feature Selection Techniques

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/zaheer/Week-10/Feature_Selection/mobile_dataset.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.duplicated().head().nunique() # find no. of dup
df.duplicated() # find dup
df.drop_duplicates() # drop duplicates
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# Univariate selection

# %%
x=df.iloc[ : , : -1]
y=df['price_range']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
SKB=SelectKBest(score_func=chi2,k=20)
ft=SKB.fit(x,y)
ft
# Out:
# SelectKBest(k=20, score_func=<function chi2 at 0x7fec58112320>)

# %%
ft.scores_
# Out:
# array([1.41298666e+04, 7.23232323e-01, 6.48365906e-01, 6.31010795e-01,
#        1.01351665e+01, 1.52157239e+00, 8.98391244e+01, 7.45819631e-01,
#        9.59728626e+01, 9.09755558e+00, 9.18605355e+00, 1.73635695e+04,
#        9.81058675e+03, 9.31267519e+05, 9.61487832e+00, 1.64803191e+01,
#        1.32364000e+01, 3.27642810e-01, 1.92842942e+00, 4.22090730e-01])

# %%
# pd.DataFrame(ft.scores_)
df_s=pd.DataFrame(ft.scores_,columns=["Scores"])
df_s
# Out:
#            Scores
# 0    14129.866576
# 1        0.723232
# 2        0.648366
# 3        0.631011
# 4       10.135166
# 5        1.521572
# 6       89.839124
# 7        0.745820
# 8       95.972863
# 9        9.097556
# 10       9.186054
# 11   17363.569536
# 12    9810.586750
# 13  931267.519053
# 14       9.614878
# 15      16.480319
# 16      13.236400
# 17       0.327643
# 18       1.928429
# 19       0.422091

# %%
df_col=pd.DataFrame(x.columns)
col_rank=pd.concat([df_col,df_s],axis=1)
col_rank
# Out:
#                 0         Scores
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
col_rank.columns=['Features','Scores']
col_rank
# Out:
#          Features         Scores
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
col_rank.sort_index(ascending=False)
col_rank.sort_index(ascending=True)
# Out:
#          Features         Scores
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091

# %%
col_rank.nlargest(10,'Scores')
# Out:
#          Features         Scores
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# Feature Importance

# %%
from  sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model=ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.06132602 0.02016841 0.03374229 0.01935337 0.0318579  0.01770874
#  0.03461158 0.03314568 0.03646542 0.03341616 0.03273996 0.04656931
#  0.04876551 0.39471948 0.03483325 0.03395474 0.03510768 0.01398068
#  0.01798164 0.01955217]

# %%
rank_feature=pd.Series(model.feature_importances_,index=x.columns)
rank_feature.nlargest(10).plot(kind='barh')
plt.tittle('')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Co-relation

# %%
import seaborn as sns
corr=df.iloc[ : , : -1].corr()
corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
top_feature=corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df[top_feature].corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# remove the corelated fearture

# %%
threshold=0.8

# %%
# find and remove correlated features
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr
correlation(df.iloc[ : , : -1],threshold=0.5)
# Out:
# {'pc', 'px_width', 'sc_w', 'three_g'}

# %%
from sklearn.feature_selection import mutual_info_classif

mutual_info=mutual_info_classif(x,y)
mutual_data=pd.Series(mutual_info,index=x.columns)
mutual_data.sort_values(ascending=False)
# Out:
# ram              0.848304
# battery_power    0.027391
# px_width         0.026535
# px_height        0.025280
# mobile_wt        0.014793
# m_dep            0.010727
# wifi             0.009551
# dual_sim         0.009451
# n_cores          0.006577
# fc               0.006404
# int_memory       0.006036
# four_g           0.000000
# blue             0.000000
# clock_speed      0.000000
# sc_h             0.000000
# sc_w             0.000000
# talk_time        0.000000
# three_g          0.000000
# touch_screen     0.000000
# pc               0.000000
# dtype: float64
